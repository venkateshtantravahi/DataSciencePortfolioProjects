# %% [markdown]
# #Covid Traker
# *Basic View of the countries with the status of covid \
#   1.Confirmed \
#   2.Global \
#   3.Recovered*
#
# *Here are some of the packages that you needed to be imported for working on the data \
#   pandas,numpy,some ipywidgets mentioned in below cell*

# %%
#import packages
from __future__ import print_function

import pandas as pd
import numpy as np
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# ###Reading the Data using pandas df=dataFrame
# *There are totally four csv files of the data with regards to country and state wise and they are time-series* \
# *You can get the csv files from the following link:* \
# [covidData](https://drive.google.com/drive/folders/1J_E_CRH5Owsetv0uSnmVT2GEqFCUGjPD?usp=sharing)

# %%
death_df = pd.read_csv('time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('time_series_covid19_recovered_global.csv')
country_df = pd.read_csv('cases_country.csv')

# %% [markdown]
# ###Visualizing the DF
# *Here you can see the first five records of the following read data*

# %%
death_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  10/22/20  10/23/20  10/24/20
# 0            NaN    Afghanistan  33.93911  ...      1505      1507      1511
# 1            NaN        Albania  41.15330  ...       465       469       473
# 2            NaN        Algeria  28.03390  ...      1888      1897      1907
# 3            NaN        Andorra  42.50630  ...        63        69        69
# 4            NaN         Angola -11.20270  ...       260       265       267
#
# [5 rows x 281 columns]

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  10/22/20  10/23/20  10/24/20
# 0            NaN    Afghanistan  33.93911  ...     40626     40687     40768
# 1            NaN        Albania  41.15330  ...     18250     18556     18858
# 2            NaN        Algeria  28.03390  ...     55357     55630     55880
# 3            NaN        Andorra  42.50630  ...      3811      4038      4038
# 4            NaN         Angola -11.20270  ...      8582      8829      9026
#
# [5 rows x 281 columns]

# %%
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  10/22/20  10/23/20  10/24/20
# 0            NaN    Afghanistan  33.93911  ...     33831     34010     34023
# 1            NaN        Albania  41.15330  ...     10395     10466     10548
# 2            NaN        Algeria  28.03390  ...     38618     38788     38932
# 3            NaN        Andorra  42.50630  ...      2470      2729      2729
# 4            NaN         Angola -11.20270  ...      3305      3384      3461
#
# [5 rows x 281 columns]

# %%
country_df.head()
# Out:
#   Country_Region          Last_Update       Lat  ...  Mortality_Rate  UID  ISO3
# 0    Afghanistan  2020-10-25 08:24:38  33.93911  ...        3.706338    4   AFG
# 1        Albania  2020-10-25 08:24:38  41.15330  ...        2.508219    8   ALB
# 2        Algeria  2020-10-25 08:24:38  28.03390  ...        3.412670   12   DZA
# 3        Andorra  2020-10-25 08:24:38  42.50630  ...        1.708767   20   AND
# 4         Angola  2020-10-25 08:24:38 -11.20270  ...        2.958121   24   AGO
#
# [5 rows x 14 columns]

# %% [markdown]
# ###Cleaning Data
#
# *Below cell code referes to the cleaning of the data means converting the headings/labels to lower case such that we can easily manipulate as it is case-sensitive and changing the label values to single label value as that it will be easy while refering*

# %%
# data cleaning

# renaming the df column names to lowercase
country_df.columns = map(str.lower, country_df.columns)
confirmed_df.columns = map(str.lower, confirmed_df.columns)
death_df.columns = map(str.lower, death_df.columns)
recovered_df.columns = map(str.lower, recovered_df.columns)

# changing province/state to state and country/region to country
confirmed_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
recovered_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
death_df = death_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
country_df = country_df.rename(columns={'country_region': 'country'})
country_df.head()
# Out:
#        country          last_update       lat  ...  mortality_rate  uid  iso3
# 0  Afghanistan  2020-10-25 08:24:38  33.93911  ...        3.706338    4   AFG
# 1      Albania  2020-10-25 08:24:38  41.15330  ...        2.508219    8   ALB
# 2      Algeria  2020-10-25 08:24:38  28.03390  ...        3.412670   12   DZA
# 3      Andorra  2020-10-25 08:24:38  42.50630  ...        1.708767   20   AND
# 4       Angola  2020-10-25 08:24:38 -11.20270  ...        2.958121   24   AGO
#
# [5 rows x 14 columns]

# %% [markdown]
# *Sorting the cleaned data to visualize *

# %%
sorted_countries = country_df.sort_values('confirmed',ascending = False).head(10)

# %%
sorted_countries
# Out:
#        country          last_update        lat  ...  mortality_rate  uid  iso3
# 175         US  2020-10-25 08:24:38  40.000000  ...        2.622170  840   USA
# 79       India  2020-10-25 08:24:38  20.593684  ...        1.507144  356   IND
# 23      Brazil  2020-10-25 08:24:38 -14.235000  ...        2.916068   76   BRA
# 140     Russia  2020-10-25 08:24:38  61.524000  ...        1.720810  643   RUS
# 62      France  2020-10-25 08:24:38  46.227600  ...        3.184042  250   FRA
# 6    Argentina  2020-10-25 08:24:38 -38.416100  ...        2.646079   32   ARG
# 159      Spain  2020-10-25 08:24:38  40.463667  ...        3.321952  724   ESP
# 37    Colombia  2020-10-25 08:24:38   4.570900  ...        2.977044  170   COL
# 113     Mexico  2020-10-25 08:24:38  23.634500  ...       10.007104  484   MEX
# 134       Peru  2020-10-25 08:24:38  -9.190000  ...        3.853741  604   PER
#
# [10 rows x 14 columns]

# %% [markdown]
# *Highlighting the table columns with some colors to easy view of required data*

# %%
def highlightColor(x):
    r = 'background-color: red'
    p = 'background-color: purple'
    g = 'background-color: grey'
    temp_df = pd.DataFrame('',index = x.index, columns = x.columns)
    temp_df.iloc[:,4] = p
    temp_df.iloc[:,5] = r
    temp_df.iloc[:,6] = g
    return temp_df

sorted_countries.style.apply(highlightColor, axis = None)
# Out:
# <style  type="text/css" >
# #T_27f4c56a_182c_11eb_98ef_0242ac1c0002row0_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row1_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row2_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row3_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row4_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row5_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row6_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row7_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row8_col4,#T_27f4c56a_182c_11eb_98ef_0242ac1c0002row9_col4{
#             background-color:  purple;
# ...

# %% [markdown]
# Importing plotly , plotly is a library like matplotlib but it is dynamic and will get updated then and there itself with out re-running the data

# %%
import plotly.express as px

# %% [markdown]
# plotting a scatter plot of sorted data that is top list of countries and thier scale of covid cases

# %%
fig = px.scatter(sorted_countries.head(10),x='country',y='confirmed',size='confirmed',color='country',hover_name='country',size_max=60)

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b576fec9-ffc7-460c-b36d-c08ea7a0b5a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b576fec9-ffc7-460c-b36d-c08ea7a0b5a9")) {
#                     Plotly.newPlot(
#                         'b576fec9-ffc7-460c-b36d-c08ea7a0b5a9',
# ...

# %% [markdown]
# Plotting a graph of confirmed and death cases where we can see a graph and change the data dynamically according to what we want to visualize

# %%
import plotly.graph_objects as go

def plotCasesForCountry(country):
    labels = ['confirmed','deaths']
    colors = ['blue','red']
    mod_size = [6,8]
    line_size = [4,5]

    dfList = [confirmed_df, death_df]

    figure = go.Figure()

    for i,df in enumerate(dfList):
        if country == 'world' or country == 'World':
            x_data = np.array(list(df.iloc[:,5:].columns))
            y_data = np.sum(np.asarray(df.iloc[:,5:]),axis=0)
        else:
            x_data = np.array(list(df.iloc[:,5:].columns))
            y_data = np.sum(np.asarray(df[df['country']==country].iloc[:,5:]),axis=0)
        fig.add_trace(go.Scatter(x=x_data, y=y_data, mode='lines+markers',
        name=labels[i],
        line=dict(color=colors[i], width=line_size[i]),
        connectgaps=True,
        text = "Total " + str(labels[i]) +": "+ str(y_data[-1])
        ));
    fig.show()

#plotCasesForCountry('India')
interact(plotCasesForCountry,country='World')
# Out:
# interactive(children=(Text(value='World', description='country'), Output()), _dom_classes=('widget-interact',)…
# <function __main__.plotCasesForCountry>

# %% [markdown]
# importing folium , folium is library where we can plot dist geographical plots

# %%
import folium

# %% [markdown]
# plotting the geographical plot for the cases across the world

# %%
world_map = folium.Map(location=[11,0], tiles="cartodbpositron", zoom_start=2, max_zoom = 6, min_zoom = 2)


for i in range(0,len(confirmed_df)):
    folium.Circle(
        location=[confirmed_df.iloc[i]['lat'], confirmed_df.iloc[i]['long']],
        fill=True,
        radius=(int((np.log(confirmed_df.iloc[i,-1]+1.00001)))+0.2)*50000,
        color='red',
        fill_color='indigo',
        tooltip = "<div style='margin: 0; background-color: black; color: white;'>"+
                    "<h4 style='text-align:center;font-weight: bold'>"+confirmed_df.iloc[i]['country'] + "</h4>"
                    "<hr style='margin:10px;color: white;'>"+
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
                        "<li>Confirmed: "+str(confirmed_df.iloc[i,-1])+"</li>"+
                        "<li>Deaths:   "+str(death_df.iloc[i,-1])+"</li>"+
                        "<li>Death Rate: "+ str(np.round(death_df.iloc[i,-1]/(confirmed_df.iloc[i,-1]+1.00001)*100,2))+ "</li>"+
                    "</ul></div>",
        ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
